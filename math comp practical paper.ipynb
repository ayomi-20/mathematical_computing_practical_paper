# %% [markdown]
# ## question five

# %% [markdown]
# ### part(i)

# %%
import numpy as np

# %%
import pandas as pd

# %%
A = np.array([[1,0.2,0.5],[0.2,1,0.8],[0.5,0.8,1]]) #Creating a matrix
print(A)
# Out:
# [[1.  0.2 0.5]
#  [0.2 1.  0.8]
#  [0.5 0.8 1. ]]

# %%
A.T #Transpose of a matrix
# Out:
# array([[1. , 0.2, 0.5],
#        [0.2, 1. , 0.8],
#        [0.5, 0.8, 1. ]])

# %% [markdown]
# ### part(ii)

# %%
determinant = np.linalg.det(A)
print(determinant)
# Out:
# 0.2299999999999999

# %% [markdown]
# ### part(iii)

# %% [markdown]
# ## question six

# %% [markdown]
# ### part (i)

# %%
from numpy import random
Y = random.normal(size = (1000)) 
print(Y) #Generating 1000 random sample
# Out:
# [ 8.61458873e-02  2.14878940e-01 -3.24525796e-01 -2.85691760e-01
#   2.26252479e-01 -6.99141782e-01  8.15343208e-01 -7.86383744e-01
#   4.45459529e-01  1.45866655e-02 -1.13123320e+00  5.31190547e-01
#   6.87404801e-01  4.69554954e-01 -4.54375733e-02 -1.65333264e+00
#  -1.23799707e+00 -4.04881507e-01  4.64943911e-01 -3.44985171e-02
#   1.01165595e+00 -8.21920639e-01 -1.27786526e+00  1.07989975e-01
#  -1.09253430e+00  2.22515771e-01  2.83414503e-01 -3.87914823e-01
#   9.11762063e-01 -1.14806452e+00 -5.31946406e-01  4.46394664e-01
#   1.30566081e+00  1.84260734e-03 -3.47704028e-02  8.07896025e-02
#   6.42103705e-01  7.82503130e-01 -3.71468838e-01  1.63558156e+00
#  -5.73428211e-01 -5.89953638e-01 -6.39140306e-01  1.30250343e+00
#  -2.47273811e-01 -1.44952996e+00  5.44419691e-01  9.17108328e-02
#   1.32602170e+00  1.29313875e+00  6.30515951e-01 -3.46922806e-02
#   1.15364915e-01 -1.78524697e+00  8.03824620e-01  6.89373911e-01
# ...

# %% [markdown]
# ### part(iii)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(Y,color="ORANGE")
plt.title("Visualisation of poisson distribution")
plt.show()
